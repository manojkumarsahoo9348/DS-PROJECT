# %% [markdown]
# # IRIS DATASET VISUALIZATION(SEABORN,MATPLOTLIB)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_excel(r"C:\Users\hp\OneDrive\Desktop\Irisdataset1.xlsx")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # ***Bar Plot***
# Here the frequency of the observation is plotted.In this case we
# are plotting the frequency of the three species in the Iris
# Dataset

# %%
sns.countplot(x='Species',data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %% [markdown]
# # ***Joint Plot***
# Jointplot is seaborn library specific and can be used to quickly
# visualize and analyze the relationship between two variables and
# describe their individual distributions on the same plot.

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris)

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris,kind='reg')

#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',kind='resid',data=iris)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # FacetGrid Plot

# %%
Facet_grid=sns.FacetGrid(data=iris,hue='Species',height=6)
Facet_grid.map(plt.scatter,'SepalLengthCm','SepalWidthCm')
Facet_grid.add_legend()

# %% [markdown]
# ***Boxplot or Whisker plot***
# Box plot was was first introduced in year 1969
# by Mathematician John Tukey.Box plot give a statical summary
# of the features being plotted.Top line represent the max value,top
# edge of box is third Quartile, middle edge represents the median,bottom
# edge represents the first quartile value.The bottom most line
# respresent the minimum value of the feature.The height of the box
# is called as Interquartile range.The black dots on the plot
# represent the outlier values in the data.

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=iris,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.4,orient='v',dodge=False)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
iris.boxplot(by='Species',figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %% [markdown]
# # Strip Plot

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %% [markdown]
# # combining box plot and strip plot

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='SepalLengthCm',data=iris)
fig=sns.stripplot(x='Species',y='SepalLengthCm',jitter=True,data=iris,edgecolor='gray')

# %% [markdown]
# # ***Violin Plot***
# It is used to visualize the distribution of data and its probability
# distribution.This chart is a combination of a Box Plot and a Density
# Plot that is rotated and placed on each side, to show the distribution
# shape of the data. The thick black bar in the centre represents the
# interquartile range, the thin black line extended from it represents
# the 95% confidence intervals, and the white dot is the median.Box Plots
# are limited in their display of the data, as their visual simplicity tends
# to hide significant details about how values in the data are distributed

# %%
fig=sns.violinplot(x='Species',y='SepalLengthCm',data=iris)

# %%
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %% [raw]
# *** Pair Plot***
# A “pairs plot” is also known as a scatterplot, in which one variable
# in the same data row is matched with another variable's value,
# like this: Pairs plots are just elaborations on this, showing all
# variables paired with all the other variables.

# %%
sns.pairplot(data=iris,kind='scatter')

# %%
sns.pairplot(data=iris,hue='Species')

# %% [markdown]
# # *** Heat Map ***
# Heat Map is used to find out the correlation between different
# features in the dataset.High positive or negative value shows
# that the features have high correlation.This helps us to select
# the parmeters for machine learning.

# %%
sns.heatmap(iris.select_dtypes(include=[np.number]).corr(), annot=True, cmap='cubehelix', linewidths=1, square=True,linecolor='k',mask=False, vmin=-1, vmax=1, cbar_kws={"orientation": "vertical"}, cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# # ***Distribution plot:***
# The distribution plot is suitable for comparing range and
# distribution for groups of numerical data. Data is plotted
# as value points along an axis. You can choose to display only
# the value points to see the distribution of values, a bounding
# box to see the range of values, or a combination of both as
# shown here.The distribution plot is not relevant for detailed
# analysis of the data as it deals with a summary of the data
# distribution.

# %%
iris.hist(edgecolor='black',linewidth=1.2)
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %% [markdown]
# # ***Swarm plot***
# It looks a bit like a friendly swarm of bees buzzing about
# their hive. More importantly, each data point is clearly visible
# and no data are obscured by overplotting.A beeswarm plot
# improves upon the random jittering approach to move data points
# the minimum distance away from one another to avoid overlays.
# The result is a plot where you can see each distinct data point,
# like shown in below plot

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.set(style='darkgrid')
fig=plt.gcf()
fig.set_size_inches(10,7)
sns.swarmplot(x='Species',y='PetalLengthCm',data=iris,hue='Species')
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.set(style='whitegrid')
fig=plt.gcf()
fig.set_size_inches(10,7)
sns.violinplot(x="Species", y="PetalLengthCm",data=iris)
sns.swarmplot(x="Species", y="PetalLengthCm",data=iris,color='white',edgecolor='black')
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# # ***LM PLOT***
# An "lmplot" (linear model plot) is a type of data visualization
# in the Seaborn library, which is built on top of Matplotlib
# and is designed for statistical data visualization in Python.
# An lmplot is used to create a scatter plot with regression lines
# to visualize the relationship between two numerical variables.

# %%
sns.lmplot(x="PetalLengthCm", y="PetalWidthCm",data=iris)

# %% [markdown]
# # ***FacetGrid***
# FacetGrid is a class in the Seaborn data visualization library,
# which is built on top of Matplotlib. It's used to create a grid
# of subplots, where each subplot displays a subset of your data.
# This is particularly useful when you want to compare and
# visualize relationships between multiple variables or categories
# in your dataset.

# %%
b=sns.FacetGrid(iris, hue="Species", height=6)
b.map(sns.kdeplot, "PetalLengthCm")
b.add_legend()
plt.ioff()

# %% [markdown]
# # ***Boxen Plot***

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
sns.boxenplot(x='Species',y='SepalLengthCm',data=iris)
plt.show()

# %% [markdown]
# # ***Distplot***
# It helps us to look at the distribution of a single variable.
# Kde shows the density of the distribution

# %%
sns.distplot(iris['SepalLengthCm'],kde=True,bins=20)
plt.show()

# %% [markdown]
# # DATA PREPROCESSING

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
iris['Species']=le.fit_transform(iris['Species'])
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
iris['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
iris.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species            int32
# dtype: object

# %% [markdown]
# # MODEL BUILDING

# %%
x=iris.iloc[:,[0,1,2,3]]
print(x.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y=iris.iloc[:,-1]
print(y.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 137            6.4           3.1            5.5           1.8
# 84             5.4           3.0            4.5           1.5
# 27             5.2           3.5            1.5           0.2
# 127            6.1           3.0            4.9           1.8
# 132            6.4           2.8            5.6           2.2
# ..             ...           ...            ...           ...
# 9              4.9           3.1            1.5           0.1
# 103            6.3           2.9            5.6           1.8
# 67             5.8           2.7            4.1           1.0
# 117            7.7           3.8            6.7           2.2
# 47             4.6           3.2            1.4           0.2
#
# [120 rows x 4 columns]

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114            5.8           2.8            5.1           2.4
# 62             6.0           2.2            4.0           1.0
# 33             5.5           4.2            1.4           0.2
# 107            7.3           2.9            6.3           1.8
# 7              5.0           3.4            1.5           0.2
# 100            6.3           3.3            6.0           2.5
# 40             5.0           3.5            1.3           0.3
# 86             6.7           3.1            4.7           1.5
# 76             6.8           2.8            4.8           1.4
# 71             6.1           2.8            4.0           1.3
# 134            6.1           2.6            5.6           1.4
# 51             6.4           3.2            4.5           1.5
# 73             6.1           2.8            4.7           1.2
# 54             6.5           2.8            4.6           1.5
# ...

# %%
y_train
# Out:
# 137    2
# 84     1
# 27     0
# 127    2
# 132    2
#       ..
# 9      0
# 103    2
# 67     1
# 117    2
# 47     0
# Name: Species, Length: 120, dtype: int32

# %%
y_test
# Out:
# 114    2
# 62     1
# 33     0
# 107    2
# 7      0
# 100    2
# 40     0
# 86     1
# 76     1
# 71     1
# 134    2
# 51     1
# 73     1
# 54     1
# 63     1
# 37     0
# 78     1
# 90     1
# 45     0
# 16     0
# 121    2
# 66     1
# 24     0
# 8      0
# 126    2
# 22     0
# 44     0
# 97     1
# 93     1
# 26     0
# Name: Species, dtype: int32

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
print(x.head()),print(y.head())
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32
# (None, None)

# %%
#create an train a logistic regression model
lmodel=LogisticRegression(max_iter=1000,random_state=42)
lmodel.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
#Make a prediction pn the test set
y_pred=lmodel.predict(x_test)

# %%
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 1.0

# %%
confusion=confusion_matrix(y_test,y_pred)
confusion
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]], dtype=int64)

# %%
report=classification_report(y_test,y_pred)
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        11\n           1       1.00      1.00      1.00        13\n           2       1.00      1.00      1.00         6\n\n    accuracy                           1.00        30\n   macro avg       1.00      1.00      1.00        30\nweighted avg       1.00      1.00      1.00        30\n'

# %% [markdown]
# # Random Forest Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
x=iris.iloc[:,[0,1,2,3]]
y=iris.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
rmodel= RandomForestClassifier(n_estimators=100,random_state=42)
rmodel.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Make a prediction pn the test set
y_pred=rmodel.predict(x_test)

# %%
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 1.0

# %%
confusion=confusion_matrix(y_test,y_pred)
confusion
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]], dtype=int64)

# %%
report=classification_report(y_test,y_pred)
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        11\n           1       1.00      1.00      1.00        13\n           2       1.00      1.00      1.00         6\n\n    accuracy                           1.00        30\n   macro avg       1.00      1.00      1.00        30\nweighted avg       1.00      1.00      1.00        30\n'

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
dmodel= DecisionTreeClassifier(random_state=42)
dmodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#Make a prediction pn the test set
y_pred=dmodel.predict(x_test)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
accuracy = accuracy_score(y_test, y_pred) 
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 1.0

# %%
confusion
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]], dtype=int64)

# %%
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        11\n           1       1.00      1.00      1.00        13\n           2       1.00      1.00      1.00         6\n\n    accuracy                           1.00        30\n   macro avg       1.00      1.00      1.00        30\nweighted avg       1.00      1.00      1.00        30\n'

# %% [markdown]
# # KNN Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
kmodel=KNeighborsClassifier(n_neighbors=3)
kmodel.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=kmodel.predict(x_test)

# %%
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 2, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
accuracy = accuracy_score(y_test, y_pred) 
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.9666666666666667

# %%
confusion
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  6]], dtype=int64)

# %%
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        11\n           1       1.00      0.92      0.96        13\n           2       0.86      1.00      0.92         6\n\n    accuracy                           0.97        30\n   macro avg       0.95      0.97      0.96        30\nweighted avg       0.97      0.97      0.97        30\n'

# %% [markdown]
# # NAIVE BAYES CLASSIFICATION

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
nmodel=GaussianNB()
nmodel.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=kmodel.predict(x_test)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 2, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
accuracy = accuracy_score(y_test, y_pred) 
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.9666666666666667

# %%
confusion
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  6]], dtype=int64)

# %%
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        11\n           1       1.00      0.92      0.96        13\n           2       0.86      1.00      0.92         6\n\n    accuracy                           0.97        30\n   macro avg       0.95      0.97      0.96        30\nweighted avg       0.97      0.97      0.97        30\n'

# %% [markdown]
# # RESULT

# %% [markdown]
# 1.Accuracy of Logistic regression - 100%
# 2.Accuracy of Random forest classifier-100%
# 3.Accuracy of Decision Tree classifier-100%
# 4.Accuracy of KNN classifier-96%
# 5.Accuracy of Naive Bayes classifier-96%
